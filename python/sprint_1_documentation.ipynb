# %% [markdown]
# Task 1.1 - Environment Setup

# %% [markdown]
# Step 1: Downloading and Installing Python
# - Navigated to the official Python website at python.org.
# - Downloaded the latest stable release for my operating system.
# - Ran the installer.
# - I made sure to check the box that said "Add Python to PATH" before clicking "Install Now." This ensures Python can be accessed directly from the command prompt or terminal without directory errors.
#
# Step 2: Verifying the Installation
# To confirm that Python was installed correctly and that the system variables were properly configured, I opened my terminal and ran the following command:
# ```python
# python --version
# ```
# Output:
# ```python
# Python 3.14.5
# ```
# The terminal successfully returned the installed Python version, confirming a successful local setup and readiness for the next phase.
#
# Step 3: Setting Up the Working Environment (Jupyter Notebook)
# To support robust coding and data analysis workflows, I chose to set up Jupyter Notebook via Anaconda.
# - Downloaded the Anaconda Distribution from anaconda.com.
# - Followed the standard installation prompts, keeping the default environment settings.
# - Opened the Anaconda Navigator and launched Jupyter Notebook, which automatically opened a local server in my default web browser.
#
#
# Step 4: Running My First Script
# - Inside the Jupyter Notebook directory tree, I navigated to my designated learning repository folder.
# - Created a new notebook by selecting New > Python 3 (ipykernel).
# - In the very first cell of the notebook, I wrote and executed my line of code
# - Result: The notebook executed the script perfectly, outputting the greeting directly below the cell.
#
# Step 5: Installing Visual Studio Code (VS Code)
# - To transition into a robust, integrated development environment (IDE), I set up Visual Studio Code.
# - Navigated to the official VS Code website at code.visualstudio.com.
# - Downloaded the appropriate stable build installer for my operating system.
# - Executed the installer, keeping the default settings.
# - I ensured that the option to "Add to PATH (requires shell restart)" was checked. This allows launching VS Code directly from any terminal window using the command code ..
#
# Step 6: Configuring VS Code for Python & Jupyter
# - To enable seamless Python development and integrate notebook support within the IDE, I configured the necessary extensions.
# - Extension Marketplace: Opened VS Code and navigated to the Extensions view by clicking the Extensions icon on the Activity Bar.
# - Python Extension: Searched for and installed the official Python extension (published by Microsoft). This provides syntax highlighting, code linting, and debugging tools.
# - Jupyter Extension: Installed the official Jupyter extension to allow the execution of .ipynb files directly inside VS Code without needing to launch Anaconda Navigator.
#
# Screenshots:
# ![VsCode Extensions](image-1.png)
# ![Python Verison](image.png)

# %%
print("Hello, iQube.ox!")
# Out:
# Hello, iQube.ox!
